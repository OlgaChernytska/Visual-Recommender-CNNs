# %%
# %reload_ext autoreload
# %autoreload 2

from utils import get_embeddings, show_similar_images

# %%
## loading test set embeddings from disk and memory
folder = 'data/Embed'
embeddings, img_names = get_similarities(folder)

# calculating similarities
similarities = cosine_similarity(embeddings, embeddings)
# Out:
# Embeddings shape: (14218, 14218)

# %%
#10008, 10010
show_similar_images(12012, img_names, similarities)
